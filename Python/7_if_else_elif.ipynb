# %%
a = int(input("Enter a number: "))
a
# Out:
# 5

# %%
if a > 0 :
    print("number is positive")
# Out:
# number is positive

# %%
a = int(input("Enter a number: "))
if a % 2 == 0 :
    print(a, "is an even number")
else :
    print(a, "is an odd number")
# Out:
# 7 is an odd number

# %%
score = int(input("Enter the score: "))
if score >= 90:
    print("Grade A ")
elif score >=80:
    print("Grade B ")
elif score >=70:
    print("Grade C ")
else :
    print("Grade F ")
# Out:
# Grade F

# %%
age = int(input("Enter your age: "))
citizenship = 'yes'
if age >= 18 and citizenship == 'yes' :
    print("yes you can vote")
# Out:
# yes you can vote

# %% [markdown]
# ## Ternary Operatos

# %%
number = 15
result = "even" if number%2 == 0 else "odd"
print(result)
# Out:
# odd

# %%
import datetime
current_hour = datetime.datetime.now().hour
print(current_hour)
greetings = "good morning" if current_hour <12 else "good afternoonn" if current_hour <18 else "good evening" if current_hour <21 else "good night"
# Out:
# 10

# %%
greetings
# Out:
# 'good morning'

# %%
vehicle = input("Enter your type of vehicle: ")
max_speed = 65 if vehicle == 'car' else 55 if vehicle == 'truck' else 45
print(f"{vehicle} : {max_speed}")
# Out:
# car : 65

# %% [markdown]
# ## Match Case

# %%
day = "monday"

match day:
    case "monday":
        print("first day of week")
    case "tuesday":
        print("this is the second day of the week")
    case "wednesday" :
        print("Third day of the week")
    case _ :
        print("its just another day ")
# Out:
# first day of week
