# %% [markdown]
# # Tuples

# %%
l = [3,4,56,"danish", 4+7j,True]

# %%
type(l)
# Out:
# list

# %%
t = ()
type(t)
# Out:
# tuple

# %%
t = (3,56.4,True, "Euron", 4+5j)
t
# Out:
# (3, 56.4, True, 'Euron', (4+5j))

# %%
t[-1]
# Out:
# (4+5j)

# %%
t[::-1]
# Out:
# ((4+5j), 'Euron', True, 56.4, 3)

# %%
t[:]
# Out:
# (3, 56.4, True, 'Euron', (4+5j))

# %%
l
# Out:
# [3, 4, 56, 'danish', (4+7j), True]

# %%
l[0]
# Out:
# 3

# %%
t[0]
# Out:
# 3

# %%
l[0] = 'danish'

# %%
t[0] = 'sudh' # tuple does not support iteam assignment (Tupple -> Immuitable intitiy)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 t[0] = 'sudh' # tuple does not support iteam assignment
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = 1
b = 2
c = 7

# %%
t = 1,2,7

# %%
t
# Out:
# (1, 2, 7)

# %%
a,b,d = t

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
d
# Out:
# 7

# %%
a,b,c = 8,9,5

# %%
t
# Out:
# (1, 2, 7)

# %%
for i in t:
    print(i)
# Out:
# 1
# 2
# 7

# %%
t
# Out:
# (1, 2, 7)

# %%
t.count(1)
# Out:
# 1

# %%
t = (2,4,5,6,2,7,8,4)

# %%
t.index(2)
# Out:
# 0

# %%
list(t) #list to list
# Out:
# [2, 4, 5, 6, 2, 7, 8, 4]

# %%
tuple(l) # list to tuple
# Out:
# ('danish', 4, 56, 'danish', (4+7j), True)

# %%
t = (2,3,4,(3,4,5), (1,2,3), [1,2,3,4])

# %%
t
# Out:
# (2, 3, 4, (3, 4, 5), (1, 2, 3), [1, 2, 3, 4])

# %%
t[3]
# Out:
# (3, 4, 5)
