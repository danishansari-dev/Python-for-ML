# %%
print(True)
# Out:
# True

# %%
True + True
# Out:
# 2

# %%
True * True
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
5 > 7
# Out:
# False

# %%
2 > 1
# Out:
# True

# %%
5 < 3
# Out:
# False

# %%
4 == 4
# Out:
# True

# %%
4 ==5
# Out:
# False

# %%
(5 ==6) * 5 # Should be 0 because 5==6 is False
# Out:
# 0

# %%
5 >=3
# Out:
# True

# %%
3 >= 5
# Out:
# False

# %%
6 <= 7
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False or True
# Out:
# True

# %%
5<7 or 5>3
# Out:
# True

# %%
5 == 5 and 6 == 9
# Out:
# False

# %%
5 == 5 or 6 == 9
# Out:
# True

# %% [markdown]
# ## Operator Precidence
# not > and > or

# %%
True or False and False
# Out:
# True

# %%
(True or False) and False
# Out:
# False

# %%
not True or False
# Out:
# False

# %%
not (True or False)
# Out:
# False

# %%
3 + 2 > 4
# Out:
# True

# %%
10 - 5 == 5 and 2 *3 == 6
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
bool(56)
# Out:
# True

# %%
bool(-89)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("Help")
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool([3,4,5])
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
a = 5
b = a

# %%
id(a)
# Out:
# 140728369050872

# %%
a is b
# Out:
# True

# %%
b is a
# Out:
# True

# %%
x = 6
y =6
id(x)
# Out:
# 140728369050904

# %%
id(y) # Should be same as id(x) because small integers are cached in Python
# Out:
# 140728369050904

# %%
x is y
# Out:
# True

# %%
q = [1,2,3]
v = [1,2,3]

# %%
id(q)
# Out:
# 1792734557760

# %%
id(v)
# Out:
# 1792734552320

# %%
q is v
# Out:
# False

# %%
q is not v
# Out:
# True
