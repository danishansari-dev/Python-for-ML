# %%
s = {}
type(s)
# Out:
# dict

# %%
s = {34}
type(s)
# Out:
# set

# %%
s = {3,4,5,6,7,8,7,6,5,4,3,4,5,6,67, "danish", "danish", "Danish"}
s
# Out:
# {3, 4, 5, 6, 67, 7, 8, 'Danish', 'danish'}

# %%
s1 = { 45,56,56,75.6,"danish", "euron", True}
s1
# Out:
# {45, 56, 75.6, True, 'danish', 'euron'}

# %%
s2 = {(4,5,6,7)}
s2
# Out:
# {(4, 5, 6, 7)}

# %%
s3 = {[2,3,4,5]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s3 = {[2,3,4,5]}
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
s4 = {5,6,7,{4,3,4}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s4 = {5,6,7,{4,3,4}}
#
# TypeError: cannot use 'set' as a set element (unhashable type: 'set')

# %%
s5 = {3,4,56,7,7,8,4,3,6,7,2,4,5,}
s5
# Out:
# {2, 3, 4, 5, 6, 7, 8, 56}

# %%
s6 = {45, 4564, 345,4,56,3,23,22222222,4,6,7,75,4,4,4,4,4,32,6,77454}
s6
# Out:
# {3, 4, 6, 7, 23, 32, 45, 56, 75, 345, 4564, 77454, 22222222}

# %%
s7 = {3,2,1}
s7
# Out:
# {1, 2, 3}

# %%
s8 = {"danish",45,6,3,5,34,3,2,244,2}
s8
# Out:
# {2, 244, 3, 34, 45, 5, 6, 'danish'}

# %%
s2
# Out:
# {(4, 5, 6, 7)}

# %%
s2.add(4)

# %%
s2
# Out:
# {(4, 5, 6, 7), 4}

# %%
s2.add("danish")

# %%
s2
# Out:
# {(4, 5, 6, 7), 4, 'danish'}

# %%
s2.update([3,4])

# %%
s2
# Out:
# {(4, 5, 6, 7), 3, 4, 'danish'}

# %%
s2.update([3,4,[4,5]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s2.update([3,4,[4,5]])
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
s2.remove(56) # use discard if don't want to get error if elemet not available
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 s2.remove(56)
#
# KeyError: 56

# %%
s2.remove(4)

# %%
s2
# Out:
# {(4, 5, 6, 7), 3, 'danish'}

# %%
s2.discard(56)

# %%
s2
# Out:
# {(4, 5, 6, 7), 3, 'danish'}

# %%
s2.pop()
# Out:
# 'danish'

# %%
s2
# Out:
# {(4, 5, 6, 7), 3}

# %%
s2.clear()

# %%
s2
# Out:
# set()

# %%
s5
# Out:
# {2, 3, 4, 5, 6, 7, 8, 56}

# %%
s8 = s5.copy()

# %%
5 in s8
# Out:
# True

# %%
345 in s8
# Out:
# False

# %%
345 not in s8
# Out:
# True

# %%
s1 = {34,5,6}
s2 = {5,6,7}

# %%
s1.union(s2)
# Out:
# {5, 6, 7, 34}

# %%
s1.intersection(s2)
# Out:
# {5, 6}

# %%
s1.difference(s2)
# Out:
# {34}

# %%
s2.difference(s1)
# Out:
# {7}

# %%
a = {1,2}
b = {1,2,3}

# %%
a.issubset(b)
# Out:
# True

# %%
b.issubset(a)
# Out:
# False

# %%
f = frozenset([3,4,5,6,7,5,6,7,88]) # frozenset is immutable

# %%
f
# Out:
# frozenset({3, 4, 5, 6, 7, 88})
