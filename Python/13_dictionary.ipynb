# %% [markdown]
# # Dictionary

# %%
d = {}
type(d)
# Out:
# dict

# %%
d = {"345": "34456665"}

# %%
d = {
     "name":"danish",
     "email_id": 'danish@gmail.com',
     "number": 7300969491,
     "subject": ["data science", "big data", 'dsa']
     }

# %%
d
# Out:
# {'name': 'danish',
#  'email_id': 'danish@gmail.com',
#  'number': 7300969491,
#  'subject': ['data science', 'big data', 'dsa']}

# %%
d1 = {"name:" 'danish'}

# %%
d1 = {23534: "danish"}

# %%
d1 = {234+7j : "danish"}

# %%
d1 = {[2,3,4] : 'danish'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 d1 = {[2,3,4] : 'danish'}
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
d1 = { "#%#" : "danish"}

# %%
d1
# Out:
# {'#%#': 'danish'}

# %%
d1 = {"name": 'danish', "name": 'danish'}

# %%
d1
# Out:
# {'name': 'danish'}

# %%
d2 = {"sub": [3,4,5,6,67,5]}

# %%
d2 = {'sub': True}

# %%
d2 = {'sub': (3,4,5,5)}

# %%
d2 = {'sub': {"name": "danish"}}

# %%
d2
# Out:
# {'sub': {'name': 'danish'}}

# %%
d
# Out:
# {'name': 'danish',
#  'email_id': 'danish@gmail.com',
#  'number': 7300969491,
#  'subject': ['data science', 'big data', 'dsa']}

# %%
d[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 d[0]
#
# KeyError: 0

# %%
d["name"]
# Out:
# 'danish'

# %%
d
# Out:
# {'name': 'danish',
#  'email_id': 'danish@gmail.com',
#  'number': 7300969491,
#  'subject': ['data science', 'big data', 'dsa']}

# %%
d['subject'][1]
# Out:
# 'big data'

# %%
d.keys()
# Out:
# dict_keys(['name', 'email_id', 'number', 'subject'])

# %%
d.values()
# Out:
# dict_values(['danish', 'danish@gmail.com', 7300969491, ['data science', 'big data', 'dsa']])

# %%
d.items()
# Out:
# dict_items([('name', 'danish'), ('email_id', 'danish@gmail.com'), ('number', 7300969491), ('subject', ['data science', 'big data', 'dsa'])])

# %%
d["key"] = [2,3,4,5,444]
d
# Out:
# {'name': 'danish',
#  'email_id': 'danish@gmail.com',
#  'number': 7300969491,
#  'subject': ['data science', 'big data', 'dsa'],
#  'key': [2, 3, 4, 5, 444],
#  'key2': [2, 3, 4, 5]}

# %%
d.pop('key')
# Out:
# [2, 3, 4, 5, 444]

# %%
d
# Out:
# {'name': 'danish',
#  'email_id': 'danish@gmail.com',
#  'number': 7300969491,
#  'subject': ['data science', 'big data', 'dsa'],
#  'key2': [2, 3, 4, 5]}

# %%
for i in d.keys():
    print(d[i])
# Out:
# danish
# danish@gmail.com
# 7300969491
# ['data science', 'big data', 'dsa']
# [2, 3, 4, 5]
