# %% [markdown]
# # Lists

# %%
l = []

# %%
l = [1,2,3,4,5,6,7]
l
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l1 = [ 4, 54, True, 3.14, 3+7j, 'danish']

# %%
l1
# Out:
# [4, 54, True, 3.14, (3+7j), 'danish']

# %%
l1[0]
# Out:
# 4

# %%
l1[:3]
# Out:
# [4, 54, True]

# %%
l1[::-1]
# Out:
# ['danish', (3+7j), 3.14, True, 54, 4]

# %%
l1[-1][1:5]
# Out:
# 'anis'

# %%
range(5)
# Out:
# range(0, 5)

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list("danish")
# Out:
# ['d', 'a', 'n', 'i', 's', 'h']

# %%
l1
# Out:
# [4, 54, True, 3.14, (3+7j), 'danish']

# %%
l1.append(3)
l1
# Out:
# [4, 54, True, 3.14, (3+7j), 'danish', 3, 3]

# %%
l1.pop()
# Out:
# 3

# %%
l1
# Out:
# [4, 54, True, 3.14, (3+7j), 'danish', 3]

# %%
l1.extend([1,2]) # Unrap data and add elemetes

# %%
l1
# Out:
# [4, 54, True, 3.14, (3+7j), 'danish', 3, 1, 2]

# %%
l1.insert(3,45)

# %%
l1
# Out:
# [4, 54, True, 45, 3.14, (3+7j), 'danish', 3, 1, 2]

# %%
l1.insert(100,464)

# %%
l1
# Out:
# [4, 54, True, 45, 3.14, (3+7j), 'danish', 3, 1, 2, 464]

# %%
l1.remove(1)

# %%
l1
# Out:
# [4, 54, 45, 3.14, (3+7j), 'danish', 3, 1, 2, 464]

# %%
l1.remove('danish')

# %%
l1
# Out:
# [4, 54, 45, 3.14, (3+7j), 3, 1, 2, 464]

# %%
l1.remove("euron")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 l1.remove("euron")
#
# ValueError: list.remove(x): x not in list

# %%
l1.pop()
# Out:
# 464

# %%
l1
# Out:
# [4, 54, 45, 3.14, (3+7j), 3, 1, 2]

# %%
l1.pop(3)
# Out:
# 3.14

# %%
l1
# Out:
# [4, 54, 45, (3+7j), 3, 1, 2]

# %%
l1.pop(3)
# Out:
# (3+7j)

# %%
l1
# Out:
# [4, 54, 45, 3, 1, 2]

# %%
l1.sort()

# %%
l1
# Out:
# [1, 2, 3, 4, 45, 54]

# %%
l1.index(1)
# Out:
# 0

# %%
l1.append(1)

# %%
l1
# Out:
# [1, 2, 3, 4, 45, 54, 1]

# %%
l1.index(1)
# Out:
# 0

# %%
l1.reverse()

# %%
l1
# Out:
# [1, 54, 45, 4, 3, 2, 1]

# %%
l1.count(1)
# Out:
# 2

# %%
l = [3,4,5,6]

# %%
l
# Out:
# [3, 4, 5, 6]

# %%
l1 = l # deep copy - referes same data don't make another copy

# %%
l
# Out:
# [3, 4, 5, 6]

# %%
l2 = l.copy() # don't reffer to same memory (shollow copy)

# %%
l2
# Out:
# [3, 4, 5, 6]

# %%
l[0]
# Out:
# 3

# %%
l[0] = 'danish'

# %%
l1
# Out:
# ['danish', 4, 5, 6]

# %%
l2
# Out:
# [3, 4, 5, 6]

# %%
6 in l1
# Out:
# True

# %%
l1* 4
# Out:
# ['danish', 4, 5, 6, 'danish', 4, 5, 6, 'danish', 4, 5, 6, 'danish', 4, 5, 6]

# %%
l1
# Out:
# ['danish', 4, 5, 6]

# %%
l2
# Out:
# [3, 4, 5, 6]

# %%
l1+l2
# Out:
# ['danish', 4, 5, 6, 3, 4, 5, 6]

# %%
l = ['danish', 'ansari']

# %%
" ".join(l)
# Out:
# 'danish ansari'

# %%
s = 'danishansari'

# %%
s.split("h")
# Out:
# ['danis', 'ansari']

# %%
l = [5,6,7,[4,5,6,"danish"],[5,6,7,8]]

# %%
l[4][2]
# Out:
# 7

# %%
for i in l:
    print(i)
# Out:
# 5
# 6
# 7
# [4, 5, 6, 'danish']
# [5, 6, 7, 8]

# %%
for i in l:
    if type(i) == list:
        print(i)
# Out:
# [4, 5, 6, 'danish']
# [5, 6, 7, 8]

# %%
l = [5,6,7,8,9,9]

# %%
max(l)
# Out:
# 9

# %%
min(l)
# Out:
# 5
