# %%
s = "danish"

# %%
s1 ='dan'

# %%
type(s)
# Out:
# str

# %%
type(s1)
# Out:
# str

# %%
s2 = """my name is danish I love coding in python"""

# %%
s2
# Out:
# 'my name is danish I love coding in python'

# %%
type(s2)
# Out:
# str

# %%
s3 = 'don't'
# Out:
#   Cell In[17], line 1
#     s3 = 'don't'
#               ^
# SyntaxError: unterminated t-string literal (detected at line 1)

# %%
s3 = "don't"

# %%
s4 = 'don"n'

# %%
a = "euron"

# %%
a[0]
# Out:
# 'e'

# %%
a[-1]
# Out:
# 'n'

# %%
a
# Out:
# 'euron'

# %%
a[0:2]
# Out:
# 'eu'

# %%
a[0:4]
# Out:
# 'euro'

# %%
a[0:3]
# Out:
# 'eur'

# %%
a[0:3:2]
# Out:
# 'er'

# %%
a[::-1]
# Out:
# 'norue'
