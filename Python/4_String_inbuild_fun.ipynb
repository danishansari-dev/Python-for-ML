# %%
s = 'euron'

# %%
s.upper()
# Out:
# 'EURON'

# %%
s
# Out:
# 'euron'

# %%
s = s.upper()

# %%
s
# Out:
# 'EURON'

# %%
s.lower()
# Out:
# 'euron'

# %%
s = "danish ansari"
s.capitalize()
# Out:
# 'Danish ansari'

# %%
s.title()
# Out:
# 'Danish Ansari'

# %%
s1 = 'danish Ansari'

# %%
s1.swapcase()
# Out:
# 'DANISH aNSARI'

# %%
s1.casefold()
# Out:
# 'danish ansari'

# %%
s1
# Out:
# 'danish Ansari'

# %%
s = "euron is my company"

# %%
s.find("my")
# Out:
# 9

# %%
s.find("danish")
# Out:
# -1

# %%
s.index("my")
# Out:
# 9

# %%
s.index("danish")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 s.index("danish")
#
# ValueError: substring not found

# %%
s
# Out:
# 'euron is my company'

# %%
s.count('n')
# Out:
# 2

# %%
s.isalpha() # returns false because of spaces
# Out:
# False

# %%
s1 = "danish"

# %%
s1.isalpha() # returns true because all characters are alphabets
# Out:
# True

# %%
s1.isalnum() # returns true because all characters are alphanumeric
# Out:
# True
