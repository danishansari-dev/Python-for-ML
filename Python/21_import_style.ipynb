# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
import math as m # m as alias mean you can use m insted of math

# %%
m.sqrt(56)
# Out:
# 7.483314773547883

# %%
# pip install numpy, pandas

# %%
import numpy as np
import pandas as pd

# %%
import math

# %%
from math import sqrt, pi

# %%
pi
# Out:
# 3.141592653589793

# %%
sqrt(45)
# Out:
# 6.708203932499369

# %%
from math import * # Star is wild-card means import all the functions of math

# %%
log(4)
# Out:
# 1.3862943611198906

# %%
# Out:
# 3.141592653589793
