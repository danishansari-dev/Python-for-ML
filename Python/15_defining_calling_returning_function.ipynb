# %% [markdown]
# # Defining Calling and Returning Function

# %%
l = [3,4,5,6,7,8]

# %%
type(l)
# Out:
# list

# %%
l1 = []
for i in l :
    if i % 2 ==0 :
        print (i)
        l1.append(i)
# Out:
# 4
# 6
# 8

# %%
l1
# Out:
# [4, 6, 8]

# %%
len(l), type(l)
# Out:
# (6, list)

# %%
def test():
    pass

# %%
def test1():
    print("Hey there! I'm jaadugarh")

# %%
test1()
# Out:
# Hey there! I'm jaadugarh

# %%
a = test1()
# Out:
# Hey there! I'm jaadugarh

# %%
a

# %%
a + 'euron'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 a + 'euron'
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
type(test1())
# Out:
# Hey there! I'm jaadugarh
# NoneType

# %%
def test2():
    return "mai hun ziyaan"

# %%
type(test2())
# Out:
# str

# %%
test2() + ' jaadugarh'
# Out:
# 'mai hun ziyaan jaadugarh'

# %%
def test3():
    return "danish", 23,34.54

# %%
test3()
# Out:
# ('danish', 23, 34.54)

# %%
type(test3())
# Out:
# tuple

# %%
a,b,c = test3()

# %%
a
# Out:
# 'danish'

# %%
b
# Out:
# 23

# %%
c
# Out:
# 34.54

# %%
def test4(a,b):
    return a+b

# %%
test4()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 test4()
#
# TypeError: test4() missing 2 required positional arguments: 'a' and 'b'

# %%
test4(4,5)
# Out:
# 9

# %%
def sub(a,b):
    return a-b

# %%
sub(5,2)
# Out:
# 3

# %%
def even(a):
    return a%2 == 0

# %%
even(5)
# Out:
# False

# %%
def pow(x,y):
    return x**y

# %%
pow(2,4)
# Out:
# 16

# %%
def average(a,b,c=0):
    return (a+b+c)/3

# %%
average(5,5,5)
# Out:
# 5.0

# %%
average(3,4)
# Out:
# 2.3333333333333335

# %%
def course_discount(price, discount = 100):
    final_price = price - discount
    return final_price

# %%
course_discount(399)
# Out:
# 299

# %%
course_discount(4999,299)
# Out:
# 4700

# %%
def add(a:int,b:int): # a:int  ti only gives hints; you can add any parameters
    return a+b

# %%
add('danish','ansari')
# Out:
# 'danishansari'

# %%
add(4,5)
# Out:
# 9

# %%
def add(a,b):
    """This function is created by me danish ansari and this function 
        will take input of two integers and output of its input data
    """
    # doc string to tell if someone is viewing your code or to tell someone else
