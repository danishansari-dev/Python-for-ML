# %%
def add(a,b) :
    print(a)
    print(b)
    return a+b

# %%
add(34,55)
# Out:
# 34
# 55
# 89

# %%
add(b = 55, a = 34)
# Out:
# 34
# 55
# 89

# %%
def registration(name, mail_id, phone_no):
    print(name, mail_id, phone_no)

# %%
registration("sudhanshu", "sudhanshu@euron.one", "324534532")
# Out:
# sudhanshu sudhanshu@euron.one 324534532

# %%
registration(mail_id="sudhanshu@euron.one", name ="danish", phone_no="239752398")
# Out:
# sudhanshu sudhanshu@euron.one 239752398

# %%
def registration(name, mail_id, phone_no, batch ="python") :
    return name, mail_id, phone_no, batch

# %%
registration(name = "sudh", mail_id="sudh@euron.one", phone_no=2354353, batch="python with dsa")
# Out:
# ('sudh', 'sudh@euron.one', 2354353, 'python with dsa')
