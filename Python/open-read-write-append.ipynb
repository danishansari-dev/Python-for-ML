# %%
f = open('test.txt', 'w')

# %%
f.write("Hey! I'm Danish")
# Out:
# 15

# %%
f.close()

# %%
f = open('test.txt')

# %%
f.read()
# Out:
# "Hey! I'm Danish"

# %%
f.read()
# Out:
# ''

# %%
f = open('test.txt', 'w') # over-write it if you write anything

# %%
f.write("I am learning Data science ")
# Out:
# 27

# %%
f.close()

# %%
f = open('test.txt', 'a')

# %%
f.write("\n\they i'm learing data science")
# Out:
# 30

# %%
f.close()

# %%
f = open('test.txt', 'r')

# %%
f.read()
# Out:
# "Hey! I'm Danish\n\they i'm learing data science"

# %%
f = open('test.txt', 'r')
for i in f:
    print(i.strip())
# Out:
# Hey! I'm Danish
# hey i'm learing data science

# %%
f = open('test.txt')
f.read(5)
# Out:
# 'Hey! '

# %%
f.read(5) #pointer stays from where that stops
# Out:
# "I'm D"

# %%
f.close()

# %%
lines = ["\nfirst line \n", "second line \n", "third line \n"]

# %%
f = open('test.txt', 'a')

# %%
f.writelines(lines)

# %%
f.close()

# %%
f = open('test.txt', 'r')

# %%
f.readlines()
# Out:
# ["Hey! I'm Danish\n",
#  "\they i'm learing data science\n",
#  'first line \n',
#  'second line \n',
#  'third line \n']

# %%
f.close()

# %%
f = open('test.txt', 'r+') # read + write

# %%
f.read()
# Out:
# "Hey! I'm Danish\n\they i'm learing data science\nfirst line \nsecond line \nthird line \n"

# %%
f.write("my name is Dan")
# Out:
# 14

# %%
f.close()
