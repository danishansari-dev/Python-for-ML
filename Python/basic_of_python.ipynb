# %%
1+1
# Out:
# 2

# %%
a = 1
b = 3.4

# %%
b
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
id(b)
# Out:
# 2374362703216

# %%
b = "danish"

# %%
type(b)
# Out:
# str

# %%
c = "my name is danish"

# %%
type(c)
# Out:
# str

# %%
g = True
type(g)
# Out:
# bool

# %%
h = False
type(h)
# Out:
# bool

# %%
True + True
# Out:
# 2

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
c = 5+6j

# %%
type(c)
# Out:
# complex

# %%
c.imag
# Out:
# 6.0

# %%
c.real
# Out:
# 5.0

# %%
b = None

# %%
type(b)
# Out:
# NoneType

# %%
None == 0
# Out:
# False

# %%
None == False
# Out:
# False

# %%
id(b)
# Out:
# 140728368155456

# %%
a = '45'

# %%
a
# Out:
# '45'

# %%
type(a)
# Out:
# str

# %%
float(a)
# Out:
# 34.0

# %%
bool(a)
# Out:
# True

# %%
b = "danish"

# %%
int(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 int(b)
#
# ValueError: invalid literal for int() with base 10: 'danish'

# %%
c = 45

# %%
str(c)
# Out:
# '45'

# %%
d = 45.67
str(d)
# Out:
# '45.67'

# %%
e = True
str(e)
# Out:
# 'True'

# %%
n = "True"

# %%
type(n)
# Out:
# str

# %%
bool(n)
# Out:
# True

# %%
a = 34
b = 45.34

# %%
a+b
# Out:
# 79.34

# %%
10 + True
# Out:
# 11

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.tau
# Out:
# 6.283185307179586

# %%
math.inf
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.sin(45)
# Out:
# 0.8509035245341184

# %%
math.log(10)
# Out:
# 2.302585092994046

# %%
math.factorial(5)
# Out:
# 120
