# %% [markdown]
# # Practice

# %%
l = [1,2,3,4,"danish", "ansari", [1,2,3,4,5,6]]

# %%
l1 = []
for i in l:
    if type(i) == int or type(i) == float :
        l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
l
# Out:
# [1, 2, 3, 4, 'danish', 'ansari', [1, 2, 3, 4, 5, 6]]

# %%
l3 = []
for i in l :
    if type(i) == list :
        for j in i:
            l3.append(j)
    else:
        if type(i) == int or type(i) == float :
            l3.append(i)

# %%
l3
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4, 5, 6]

# %%
list = []

# %%
def extract_num(l):
    for i in l :
        if type(i) == list :
            for j in i:
                list.append(j)
        else:
            if type(i) == int or type(i) == float :
                list.append(i)
    return list

# %%
extract_num(l)
# Out:
# [1, 2, 3, 4]

# %%
s = "This is my string class"

# %%
len(s)
# Out:
# 23

# %%
s.find('i') #finds first occurance
# Out:
# 2

# %%
s.count('i')
# Out:
# 3

# %%
s.count('my')
# Out:
# 1

# %%
s.count('s')
# Out:
# 5

# %%
s.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s
# Out:
# 'This is my string class'

# %%
s.replace('my', 'your')
# Out:
# 'This is your string class'

# %%
marks = int(input("Enter your marks: "))
if(marks >= 75):
    print("Grade A+")
elif marks >= 60 and marks < 75:
    print("Grade A")
elif marks >=45 and marks <60 :
    print("Grade B")
else:
    print("Grade C")
# Out:
# Grade C

# %%
a = input("Hi , what's your name?")
a
# Out:
# 'Danish'

# %% [markdown]
# # List
# - Ordered collection of items.
# - Mutable (can be changed).
# - Uses square brackets `[]`.
#
# Example:
# ```python
# a = [1, 2, 3]
# a.append(4)

# %%
l = [1, 3.14, 7+ 5j, True, 'Danish']

# %%
l[0]
# Out:
# 1

# %%
l[:]
l[::]
# Out:
# [1, 3.14, (7+5j), True, 'Danish']

# %%
l[::-1]
# Out:
# ['Danish', True, (7+5j), 3.14, 1]

# %%
l[::2]
# Out:
# [1, (7+5j), 'Danish']

# %%
l[1:4:2]
# Out:
# [3.14, True]

# %%
l[0:4]
# Out:
# [1, 3.14, (7+5j), True]

# %%
l
# Out:
# [1, 3.14, (7+5j), True, 'Danish']

# %%
s = "pwskills"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
t = ['Rohit', 3, 3.5]

# %%
l + t
# Out:
# [1, 3.14, (7+5j), True, 'Danish', 'Rohit', 3, 3.5]

# %%
l
# Out:
# [1, 3.14, (7+5j), True, 'Danish']

# %%
t
# Out:
# ['Rohit', 3, 3.5]

# %%
s
# Out:
# 'pwskills'

# %%
print(l,t,s)
# Out:
# [1, 3.14, (7+5j), True, 'Danish'] ['Rohit', 3, 3.5] pwskills

# %%
l
# Out:
# [1, 3.14, (7+5j), True, 'Danish']

# %%
type(l[3])
# Out:
# bool

# %%
l[4]
# Out:
# 'Danish'

# %%
l[4][:2]
# Out:
# 'Da'

# %%
str(l[3][0:2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 str(l[3][0:2])
#
# TypeError: 'bool' object is not subscriptable

# %%
l
# Out:
# [1, 3.14, (7+5j), True, 'Danish']

# %%
l.append(5)
l
# Out:
# [1, 3.14, (7+5j), True, 'Danish', 5, 5]

# %%
l.append(s)

# %%
l
# Out:
# [1, 3.14, (7+5j), True, 'Danish', 5, 5, 'pwskills']

# %%
l.extend('sudh')

# %%
l
# Out:
# [1, 3.14, (7+5j), True, 'Danish', 5, 5, 'pwskills', 's', 'u', 'd', 'h']

# %%
l
# Out:
# [1, 3.14, (7+5j), True, 'Danish', 5, 5, 'pwskills', 's', 'u', 'd', 'h']

# %%
l.extend(3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 l.extend(3,4,5)
#
# TypeError: list.extend() takes exactly one argument (3 given)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
l + l1
# Out:
# [1,
#  3.14,
#  (7+5j),
#  True,
#  'Danish',
#  5,
#  5,
#  'pwskills',
#  's',
#  'u',
#  'd',
#  'h',
#  1,
#  2,
#  3,
#  4]

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [1,
#  3.14,
#  (7+5j),
#  True,
#  'Danish',
#  5,
#  5,
#  'pwskills',
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5]

# %%
l.append([99,98]) #adds in list of list

# %%
l
# Out:
# [1,
#  3.14,
#  (7+5j),
#  True,
#  'Danish',
#  5,
#  5,
#  'pwskills',
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  [99, 98]]

# %%
l.extend([44,55,66]) #in adds in existing list

# %%
l
# Out:
# [1,
#  3.14,
#  (7+5j),
#  True,
#  'Danish',
#  5,
#  5,
#  'pwskills',
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5,
#  [99, 98],
#  44,
#  55,
#  66]

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
l1.insert(1, "danish")

# %%
l1
# Out:
# [1, 'danish', 2, 3, 4]

# %%
l1.insert(2, [2,3,4])

# %%
l1
# Out:
# [1, 'danish', [2, 3, 4], 2, 3, 4]

# %%
l1.insert(-1, 45)

# %%
l1
# Out:
# [1, 'danish', [2, 3, 4], 2, 3, 45, 4]

# %%
l1.insert(0,45)

# %%
l1
# Out:
# [45, 1, 'danish', [2, 3, 4], 2, 3, 45, 4]

# %%
l1.pop()
# Out:
# 4

# %%
l1
# Out:
# [45, 1, 'danish', [2, 3, 4], 2, 3, 45]

# %%
l1.pop()
# Out:
# 45

# %%
l1
# Out:
# [45, 1, 'danish', [2, 3, 4], 2, 3]

# %%
l1.remove(3)

# %%
l1
# Out:
# [45, 1, 'danish', [2, 3, 4], 2]

# %%
l1[3].remove(3)

# %%
l1
# Out:
# [45, 1, 'danish', [2, 4], 2]

# %%
l1.append(4)

# %%
l1
# Out:
# [45, 1, 'danish', [2, 4], 2, 4, 4]

# %%
l1.pop()
# Out:
# 4

# %%
l1
# Out:
# [45, 1, 'danish', [2, 4], 2, 4]

# %%
l1.remove(4)

# %%
l1
# Out:
# [45, 1, 'danish', [2, 4], 2]

# %%
l1[::-1]
# Out:
# [2, [2, 4], 'danish', 1, 45]

# %%
l1
# Out:
# [45, 1, 'danish', [2, 4], 2]

# %%
l1.insert(-1, 4)

# %%
l1
# Out:
# [45, 1, 'danish', [2, 4], 4, 2]

# %%
l1.remove(2)

# %%
l1
# Out:
# [45, 1, 'danish', [2, 4], 4]

# %%
l1[::-1]
# Out:
# [4, [2, 4], 'danish', 1, 45]

# %%
l1.remove(1)

# %%
l1
# Out:
# [45, 'danish', [2, 4], 4]

# %%
l1[::-1]
# Out:
# [4, [2, 4], 'danish', 45]

# %%
l1.insert(2, 'sudh')

# %%
l1.remove('danish')

# %%
l1
# Out:
# [45, 'sudh', [2, 4], 4]

# %%
l1.reverse()

# %%
l1
# Out:
# [4, [2, 4], 'sudh', 45]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
l2 = [34,54,23,1,6,4,6,7,8,9]

# %%
l2.sort()
l2
# Out:
# [1, 4, 6, 6, 7, 8, 9, 23, 34, 54]

# %%
l4 = ['danish', 'ansari', 'data science', 'scientist']

# %%
l4.sort()
l4
# Out:
# ['ansari', 'danish', 'data science', 'scientist']

# %%
l4.reverse
# Out:
# <function list.reverse()>

# %%
l4
# Out:
# ['scientist', 'data science', 'danish', 'ansari']

# %%
l4
# Out:
# ['scientist', 'data science', 'danish', 'ansari']

# %%
l4.sort()

# %%
l4
# Out:
# ['ansari', 'danish', 'data science', 'scientist']

# %%
l4.index("danish")
# Out:
# 1

# %%
s = 'danish'

# %%
l5 = [3,4,5,6]

# %%
s[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 s[0] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
l5
# Out:
# [3, 4, 5, 6]

# %%
l5[0] = 30 #int support item assignment

# %%
l5
# Out:
# [30, 4, 5, 6]

# %%
type(l5)
# Out:
# list

# %%
type(l1)
# Out:
# list

# %%
l1
# Out:
# [4, [2, 4], 'sudh', 45]

# %%
s
# Out:
# 'danish'

# %%
s.replace('d', 'R')
# Out:
# 'Ranish'

# %%
s
# Out:
# 'danish'

# %% [markdown]
# ## Tuples

# %%
t = (2,3,4,5, 'danish', 43.56, False, 45+445j, [3,4,5])

# %%
type(t)
# Out:
# tuple

# %% [markdown]
# # Tuple
# - Ordered collection of items.
# - Immutable, cannot be changed after creation.
# - Written using parentheses `()`.
#
# Example:
# ```python
# t = (1, 2, 3)

# %%
t = (2,3,4,5,"sudh" , 45.56, False , 45+457j , [3,4,5] )

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t[-1].pop()
# Out:
# 5

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4])

# %%
t[-1].insert(-1,5)

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 5, 5, 5, 4])

# %%
t[-1].remove(5)

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 5, 4])

# %%
t[::-1]
# Out:
# ([3, 5, 4], (45+457j), False, 45.56, 'sudh', 5, 4, 3, 2)

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 5, 4])

# %%
t[0] = 'danish'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[221], line 1
# ----> 1 t[0] = 'danish'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(4)
# Out:
# 1

# %%
t.index(False)
# Out:
# 6

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 5, 4])

# %% [markdown]
# # Set
# - Unordered collection of unique elements.
# - Mutable.
# - Written using curly braces `{}` or `set()`.
#
# Example:
# ```python
# s = {1, 2, 3}

# %%
s1 = {}

# %%
type(s1)
# Out:
# dict

# %%
s2 = {2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3 = {23,45,2,'danish', 4+7j, True, (3,4,5)}
s3
# Out:
# {(3, 4, 5), (4+7j), 2, 23, 45, True, 'danish'}

# %%
type(s3)
# Out:
# set

# %%
s4 = { 2,2,2,2,3,4,5,4,3,5,'danish','danish','rohit'}

# %%
s4
# Out:
# {2, 3, 4, 5, 'danish', 'rohit'}

# %%
s4 = list(set(s4))

# %% [markdown]
# # Dictionary
# - Collection of key-value pairs.
# - Unordered before Python 3.7, insertion-ordered from Python 3.7+.
# - Mutable.
# - Written using curly braces `{}`.
#
# Example:
# ```python
# d = {"name": "Alice", "age": 25}

# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d2 = {'name' : 'Dansih', 'email' : 'danis@gmail.com', 'number' : 7300969491}
d2
# Out:
# {'name': 'Dansih', 'email': 'danis@gmail.com', 'number': 7300969491}

# %%
# Out:
# {'name': 'Dansih', 'email': 'danis@gmail.com', 'number': 7300969491}

# %%
d3 = { 234 : 'sudh', '_wer' : 'kumar', True : 2345}
d3
# Out:
# {234: 'sudh', '_wer': 'kumar', True: 2345}

# %%
d3[234], d3[True]
# Out:
# ('sudh', 2345, 2345)

# %%
d3[1]
# Out:
# 2345

# %%
d3[True]
# Out:
# 2345

# %%
d3['_wer']
# Out:
# 'kumar'

# %%
d4 = {'name':"sudh" , 'mail_id' :"ss@gmail.com" ,"name":"sudhanshu"}
